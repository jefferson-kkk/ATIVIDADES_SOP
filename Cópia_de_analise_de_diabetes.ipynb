# %% [markdown]
# <a href="https://colab.research.google.com/github/jefferson-kkk/ATIVIDADES_SOP/blob/main/C%C3%B3pia_de_analise_de_diabetes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install aif360
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.7/259.7 kB 17.2 MB/s eta 0:00:00
# ...

# %%
data['diabetes'].value_counts()
# Out:
# diabetes
# 0    91500
# 1     8500
# Name: count, dtype: int64

# %%
data['race'] = np.where{data['race:Caucasian'] == 1, 1, 0}

data = data.drop(columns=['race:AfricanAmerican, ''race:Asian', 'race:Caucasian', 'race:hispanic' 'race:Other'])

# %%
# bibliotecas para a manipulação de dados
import pandas as pd
import numpy as np

# bibliotecas para manipulação de dados e modelagem
from sklearn.model_selection import train_test_split, KFold, cross_val_predict
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_classification

# modelos de machine learning
from sklearn.linear_model import  LogisticRegression, SGDClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import AdaBoostClassifier
import sklearn.model_selection as model_selection

# from catboost import catboostclassifier
import xgboost as xgb

# métricas de avaliação
from sklearn.metrics import(
    accuracy_score, precision_score, recall_score, f1_score, roc_auc_score,
    confusion_matrix, ConfusionMatrixDisplay, classification_report
)
data = pd.read_csv('/content/diabetes_dataset.csv')

# %%
data.head()
# Out:
#    year  gender   age  ... hbA1c_level  blood_glucose_level  diabetes
# 0  2020  Female  32.0  ...         5.0                  100         0
# 1  2015  Female  29.0  ...         5.0                   90         0
# 2  2015    Male  18.0  ...         4.8                  160         0
# 3  2015    Male  41.0  ...         4.0                  159         0
# 4  2016  Female  52.0  ...         6.5                   90         0
#
# [5 rows x 16 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
